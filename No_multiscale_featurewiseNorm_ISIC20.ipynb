# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha-Akundi/Skin-Classification/blob/main/No_multiscale_featurewiseNorm_ISIC20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install -q kaggle
# from google.colab import files
# files.upload()
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/Upwork/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download cdeotte/jpeg-melanoma-256x256
! mkdir isic2020
# Out:
# Downloading jpeg-melanoma-256x256.zip to /content
#  99% 786M/791M [00:18<00:00, 34.3MB/s]
# 100% 791M/791M [00:18<00:00, 44.1MB/s]

# %%
! unzip jpeg-melanoma-256x256.zip -d isic2020
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: isic2020/train/ISIC_8512716.jpg
#   inflating: isic2020/train/ISIC_8513112.jpg
#   inflating: isic2020/train/ISIC_8513649.jpg
#   inflating: isic2020/train/ISIC_8514170.jpg
#   inflating: isic2020/train/ISIC_8514989.jpg
#   inflating: isic2020/train/ISIC_8515165.jpg
#   inflating: isic2020/train/ISIC_8515281.jpg
#   inflating: isic2020/train/ISIC_8515582.jpg
#   inflating: isic2020/train/ISIC_8515674.jpg
#   inflating: isic2020/train/ISIC_8516181.jpg
#   inflating: isic2020/train/ISIC_8516223.jpg
#   inflating: isic2020/train/ISIC_8516516.jpg
#   inflating: isic2020/train/ISIC_8516631.jpg
#   inflating: isic2020/train/ISIC_8516659.jpg
#   inflating: isic2020/train/ISIC_8516922.jpg
#   inflating: isic2020/train/ISIC_8517305.jpg
#   inflating: isic2020/train/ISIC_8517492.jpg
#   inflating: isic2020/train/ISIC_8518406.jpg
#   inflating: isic2020/train/ISIC_8519222.jpg
#   inflating: isic2020/train/ISIC_8519402.jpg
#   inflating: isic2020/train/ISIC_8519725.jpg
#   inflating: isic2020/train/ISIC_8519890.jpg
#   inflating: isic2020/train/ISIC_8519931.jpg
#   inflating: isic2020/train/ISIC_8520545.jpg
#   inflating: isic2020/train/ISIC_8521162.jpg
#   inflating: isic2020/train/ISIC_8521337.jpg
#   inflating: isic2020/train/ISIC_8521610.jpg
#   inflating: isic2020/train/ISIC_8521849.jpg
#   inflating: isic2020/train/ISIC_8521856.jpg
#   inflating: isic2020/train/ISIC_8521950.jpg
#   inflating: isic2020/train/ISIC_8523143.jpg
#   inflating: isic2020/train/ISIC_8523262.jpg
#   inflating: isic2020/train/ISIC_8523423.jpg
#   inflating: isic2020/train/ISIC_8523488.jpg
#   inflating: isic2020/train/ISIC_8523496.jpg
#   inflating: isic2020/train/ISIC_8523509.jpg
#   inflating: isic2020/train/ISIC_8523777.jpg
#   inflating: isic2020/train/ISIC_8523824.jpg
#   inflating: isic2020/train/ISIC_8524137.jpg
#   inflating: isic2020/train/ISIC_8524333.jpg
#   inflating: isic2020/train/ISIC_8524457.jpg
#   inflating: isic2020/train/ISIC_8525314.jpg
#   inflating: isic2020/train/ISIC_8525786.jpg
#   inflating: isic2020/train/ISIC_8525845.jpg
#   inflating: isic2020/train/ISIC_8526408.jpg
#   inflating: isic2020/train/ISIC_8526513.jpg
#   inflating: isic2020/train/ISIC_8526729.jpg
#   inflating: isic2020/train/ISIC_8526902.jpg
#   inflating: isic2020/train/ISIC_8526982.jpg
#   inflating: isic2020/train/ISIC_8527092.jpg
#   inflating: isic2020/train/ISIC_8527330.jpg
#   inflating: isic2020/train/ISIC_8527607.jpg
#   inflating: isic2020/train/ISIC_8527737.jpg
#   inflating: isic2020/train/ISIC_8528486.jpg
#   inflating: isic2020/train/ISIC_8528497.jpg
#   inflating: isic2020/train/ISIC_8528824.jpg
#   inflating: isic2020/train/ISIC_8529767.jpg
#   inflating: isic2020/train/ISIC_8530010.jpg
#   inflating: isic2020/train/ISIC_8530596.jpg
#   inflating: isic2020/train/ISIC_8531381.jpg
#   inflating: isic2020/train/ISIC_8531497.jpg
#   inflating: isic2020/train/ISIC_8531541.jpg
#   inflating: isic2020/train/ISIC_8531942.jpg
#   inflating: isic2020/train/ISIC_8531962.jpg
#   inflating: isic2020/train/ISIC_8532425.jpg
#   inflating: isic2020/train/ISIC_8532697.jpg
#   inflating: isic2020/train/ISIC_8533045.jpg
#   inflating: isic2020/train/ISIC_8533089.jpg
#   inflating: isic2020/train/ISIC_8534607.jpg
#   inflating: isic2020/train/ISIC_8534723.jpg
#   inflating: isic2020/train/ISIC_8534863.jpg
#   inflating: isic2020/train/ISIC_8535134.jpg
#   inflating: isic2020/train/ISIC_8535451.jpg
#   inflating: isic2020/train/ISIC_8535709.jpg
#   inflating: isic2020/train/ISIC_8535844.jpg
#   inflating: isic2020/train/ISIC_8535943.jpg
#   inflating: isic2020/train/ISIC_8536138.jpg
#   inflating: isic2020/train/ISIC_8536167.jpg
#   inflating: isic2020/train/ISIC_8536563.jpg
#   inflating: isic2020/train/ISIC_8536913.jpg
#   inflating: isic2020/train/ISIC_8537867.jpg
#   inflating: isic2020/train/ISIC_8538758.jpg
#   inflating: isic2020/train/ISIC_8539883.jpg
#   inflating: isic2020/train/ISIC_8539990.jpg
#   inflating: isic2020/train/ISIC_8540111.jpg
#   inflating: isic2020/train/ISIC_8540360.jpg
#   inflating: isic2020/train/ISIC_8540395.jpg
#   inflating: isic2020/train/ISIC_8540723.jpg
#   inflating: isic2020/train/ISIC_8541038.jpg
#   inflating: isic2020/train/ISIC_8541165.jpg
#   inflating: isic2020/train/ISIC_8541355.jpg
#   inflating: isic2020/train/ISIC_8541533.jpg
#   inflating: isic2020/train/ISIC_8542407.jpg
#   inflating: isic2020/train/ISIC_8542665.jpg
#   inflating: isic2020/train/ISIC_8543040.jpg
#   inflating: isic2020/train/ISIC_8543199.jpg
#   inflating: isic2020/train/ISIC_8543283.jpg
#   inflating: isic2020/train/ISIC_8544021.jpg
#   inflating: isic2020/train/ISIC_8544119.jpg
#   inflating: isic2020/train/ISIC_8544236.jpg
#   inflating: isic2020/train/ISIC_8544496.jpg
#   inflating: isic2020/train/ISIC_8545097.jpg
#   inflating: isic2020/train/ISIC_8545141.jpg
#   inflating: isic2020/train/ISIC_8545182.jpg
#   inflating: isic2020/train/ISIC_8545201.jpg
#   inflating: isic2020/train/ISIC_8545949.jpg
#   inflating: isic2020/train/ISIC_8546049.jpg
#   inflating: isic2020/train/ISIC_8546213.jpg
#   inflating: isic2020/train/ISIC_8546323.jpg
#   inflating: isic2020/train/ISIC_8546378.jpg
#   inflating: isic2020/train/ISIC_8546599.jpg
#   inflating: isic2020/train/ISIC_8547536.jpg
#   inflating: isic2020/train/ISIC_8547714.jpg
#   inflating: isic2020/train/ISIC_8548394.jpg
#   inflating: isic2020/train/ISIC_8549063.jpg
#   inflating: isic2020/train/ISIC_8549193.jpg
#   inflating: isic2020/train/ISIC_8549526.jpg
#   inflating: isic2020/train/ISIC_8549696.jpg
#   inflating: isic2020/train/ISIC_8549988.jpg
#   inflating: isic2020/train/ISIC_8550170.jpg
#   inflating: isic2020/train/ISIC_8550301.jpg
#   inflating: isic2020/train/ISIC_8551124.jpg
#   inflating: isic2020/train/ISIC_8551262.jpg
#   inflating: isic2020/train/ISIC_8551284.jpg
#   inflating: isic2020/train/ISIC_8551617.jpg
#   inflating: isic2020/train/ISIC_8551624.jpg
#   inflating: isic2020/train/ISIC_8552300.jpg
#   inflating: isic2020/train/ISIC_8552365.jpg
#   inflating: isic2020/train/ISIC_8552463.jpg
#   inflating: isic2020/train/ISIC_8553729.jpg
#   inflating: isic2020/train/ISIC_8554450.jpg
#   inflating: isic2020/train/ISIC_8554535.jpg
#   inflating: isic2020/train/ISIC_8555379.jpg
#   inflating: isic2020/train/ISIC_8555527.jpg
#   inflating: isic2020/train/ISIC_8555610.jpg
#   inflating: isic2020/train/ISIC_8555960.jpg
#   inflating: isic2020/train/ISIC_8556150.jpg
#   inflating: isic2020/train/ISIC_8556387.jpg
#   inflating: isic2020/train/ISIC_8556489.jpg
#   inflating: isic2020/train/ISIC_8556519.jpg
#   inflating: isic2020/train/ISIC_8556582.jpg
#   inflating: isic2020/train/ISIC_8556629.jpg
#   inflating: isic2020/train/ISIC_8556734.jpg
#   inflating: isic2020/train/ISIC_8556998.jpg
#   inflating: isic2020/train/ISIC_8557006.jpg
#   inflating: isic2020/train/ISIC_8557624.jpg
#   inflating: isic2020/train/ISIC_8558194.jpg
#   inflating: isic2020/train/ISIC_8559171.jpg
#   inflating: isic2020/train/ISIC_8559515.jpg
#   inflating: isic2020/train/ISIC_8559778.jpg
#   inflating: isic2020/train/ISIC_8560031.jpg
#   inflating: isic2020/train/ISIC_8560381.jpg
#   inflating: isic2020/train/ISIC_8560796.jpg
#   inflating: isic2020/train/ISIC_8561070.jpg
#   inflating: isic2020/train/ISIC_8561864.jpg
#   inflating: isic2020/train/ISIC_8561963.jpg
#   inflating: isic2020/train/ISIC_8562161.jpg
#   inflating: isic2020/train/ISIC_8562717.jpg
#   inflating: isic2020/train/ISIC_8562820.jpg
#   inflating: isic2020/train/ISIC_8562869.jpg
#   inflating: isic2020/train/ISIC_8563132.jpg
#   inflating: isic2020/train/ISIC_8563737.jpg
#   inflating: isic2020/train/ISIC_8563961.jpg
#   inflating: isic2020/train/ISIC_8564474.jpg
#   inflating: isic2020/train/ISIC_8564527.jpg
#   inflating: isic2020/train/ISIC_8564550.jpg
#   inflating: isic2020/train/ISIC_8564636.jpg
#   inflating: isic2020/train/ISIC_8565325.jpg
#   inflating: isic2020/train/ISIC_8565387.jpg
#   inflating: isic2020/train/ISIC_8565792.jpg
#   inflating: isic2020/train/ISIC_8566006.jpg
#   inflating: isic2020/train/ISIC_8566184.jpg
#   inflating: isic2020/train/ISIC_8566203.jpg
#   inflating: isic2020/train/ISIC_8567027.jpg
#   inflating: isic2020/train/ISIC_8567199.jpg
#   inflating: isic2020/train/ISIC_8567442.jpg
#   inflating: isic2020/train/ISIC_8568520.jpg
#   inflating: isic2020/train/ISIC_8568772.jpg
#   inflating: isic2020/train/ISIC_8569148.jpg
#   inflating: isic2020/train/ISIC_8569205.jpg
#   inflating: isic2020/train/ISIC_8569666.jpg
#   inflating: isic2020/train/ISIC_8570402.jpg
#   inflating: isic2020/train/ISIC_8570555.jpg
#   inflating: isic2020/train/ISIC_8570665.jpg
#   inflating: isic2020/train/ISIC_8570817.jpg
#   inflating: isic2020/train/ISIC_8570917.jpg
#   inflating: isic2020/train/ISIC_8571029.jpg
#   inflating: isic2020/train/ISIC_8571168.jpg
#   inflating: isic2020/train/ISIC_8571262.jpg
#   inflating: isic2020/train/ISIC_8572174.jpg
#   inflating: isic2020/train/ISIC_8572337.jpg
#   inflating: isic2020/train/ISIC_8572722.jpg
#   inflating: isic2020/train/ISIC_8572893.jpg
#   inflating: isic2020/train/ISIC_8573647.jpg
#   inflating: isic2020/train/ISIC_8573837.jpg
#   inflating: isic2020/train/ISIC_8574064.jpg
#   inflating: isic2020/train/ISIC_8574269.jpg
#   inflating: isic2020/train/ISIC_8574363.jpg
#   inflating: isic2020/train/ISIC_8574407.jpg
#   inflating: isic2020/train/ISIC_8574819.jpg
#   inflating: isic2020/train/ISIC_8575099.jpg
#   inflating: isic2020/train/ISIC_8575148.jpg
#   inflating: isic2020/train/ISIC_8575507.jpg
#   inflating: isic2020/train/ISIC_8575769.jpg
#   inflating: isic2020/train/ISIC_8575776.jpg
#   inflating: isic2020/train/ISIC_8576068.jpg
#   inflating: isic2020/train/ISIC_8576785.jpg
#   inflating: isic2020/train/ISIC_8577010.jpg
#   inflating: isic2020/train/ISIC_8577200.jpg
#   inflating: isic2020/train/ISIC_8577332.jpg
#   inflating: isic2020/train/ISIC_8577523.jpg
#   inflating: isic2020/train/ISIC_8577581.jpg
#   inflating: isic2020/train/ISIC_8577966.jpg
#   inflating: isic2020/train/ISIC_8577970.jpg
#   inflating: isic2020/train/ISIC_8578525.jpg
#   inflating: isic2020/train/ISIC_8578732.jpg
#   inflating: isic2020/train/ISIC_8579259.jpg
#   inflating: isic2020/train/ISIC_8579452.jpg
#   inflating: isic2020/train/ISIC_8579466.jpg
#   inflating: isic2020/train/ISIC_8579575.jpg
#   inflating: isic2020/train/ISIC_8580217.jpg
#   inflating: isic2020/train/ISIC_8580423.jpg
#   inflating: isic2020/train/ISIC_8580692.jpg
#   inflating: isic2020/train/ISIC_8580834.jpg
#   inflating: isic2020/train/ISIC_8582918.jpg
#   inflating: isic2020/train/ISIC_8583462.jpg
#   inflating: isic2020/train/ISIC_8584089.jpg
#   inflating: isic2020/train/ISIC_8584224.jpg
#   inflating: isic2020/train/ISIC_8584239.jpg
#   inflating: isic2020/train/ISIC_8584531.jpg
#   inflating: isic2020/train/ISIC_8584537.jpg
#   inflating: isic2020/train/ISIC_8584585.jpg
#   inflating: isic2020/train/ISIC_8584628.jpg
#   inflating: isic2020/train/ISIC_8584748.jpg
#   inflating: isic2020/train/ISIC_8584793.jpg
#   inflating: isic2020/train/ISIC_8585374.jpg
#   inflating: isic2020/train/ISIC_8585685.jpg
#   inflating: isic2020/train/ISIC_8585810.jpg
#   inflating: isic2020/train/ISIC_8586555.jpg
#   inflating: isic2020/train/ISIC_8586687.jpg
#   inflating: isic2020/train/ISIC_8586909.jpg
#   inflating: isic2020/train/ISIC_8587396.jpg
#   inflating: isic2020/train/ISIC_8587542.jpg
#   inflating: isic2020/train/ISIC_8587556.jpg
#   inflating: isic2020/train/ISIC_8587822.jpg
#   inflating: isic2020/train/ISIC_8588033.jpg
#   inflating: isic2020/train/ISIC_8588488.jpg
#   inflating: isic2020/train/ISIC_8588784.jpg
#   inflating: isic2020/train/ISIC_8588957.jpg
#   inflating: isic2020/train/ISIC_8589165.jpg
#   inflating: isic2020/train/ISIC_8589914.jpg
#   inflating: isic2020/train/ISIC_8589961.jpg
#   inflating: isic2020/train/ISIC_8590181.jpg
#   inflating: isic2020/train/ISIC_8590883.jpg
#   inflating: isic2020/train/ISIC_8591003.jpg
#   inflating: isic2020/train/ISIC_8591013.jpg
#   inflating: isic2020/train/ISIC_8591040.jpg
#   inflating: isic2020/train/ISIC_8591123.jpg
#   inflating: isic2020/train/ISIC_8591425.jpg
#   inflating: isic2020/train/ISIC_8591681.jpg
#   inflating: isic2020/train/ISIC_8591692.jpg
#   inflating: isic2020/train/ISIC_8592195.jpg
#   inflating: isic2020/train/ISIC_8592235.jpg
#   inflating: isic2020/train/ISIC_8592360.jpg
#   inflating: isic2020/train/ISIC_8592574.jpg
#   inflating: isic2020/train/ISIC_8592794.jpg
#   inflating: isic2020/train/ISIC_8592827.jpg
#   inflating: isic2020/train/ISIC_8593029.jpg
#   inflating: isic2020/train/ISIC_8593130.jpg
#   inflating: isic2020/train/ISIC_8593493.jpg
#   inflating: isic2020/train/ISIC_8593525.jpg
#   inflating: isic2020/train/ISIC_8593734.jpg
#   inflating: isic2020/train/ISIC_8593825.jpg
#   inflating: isic2020/train/ISIC_8594757.jpg
#   inflating: isic2020/train/ISIC_8595062.jpg
#   inflating: isic2020/train/ISIC_8595133.jpg
#   inflating: isic2020/train/ISIC_8595693.jpg
#   inflating: isic2020/train/ISIC_8595896.jpg
#   inflating: isic2020/train/ISIC_8596474.jpg
#   inflating: isic2020/train/ISIC_8596724.jpg
#   inflating: isic2020/train/ISIC_8596752.jpg
#   inflating: isic2020/train/ISIC_8596980.jpg
#   inflating: isic2020/train/ISIC_8597073.jpg
#   inflating: isic2020/train/ISIC_8597158.jpg
#   inflating: isic2020/train/ISIC_8597354.jpg
#   inflating: isic2020/train/ISIC_8598120.jpg
#   inflating: isic2020/train/ISIC_8598253.jpg
#   inflating: isic2020/train/ISIC_8598545.jpg
#   inflating: isic2020/train/ISIC_8598593.jpg
#   inflating: isic2020/train/ISIC_8599152.jpg
#   inflating: isic2020/train/ISIC_8599384.jpg
#   inflating: isic2020/train/ISIC_8600358.jpg
#   inflating: isic2020/train/ISIC_8600650.jpg
#   inflating: isic2020/train/ISIC_8600809.jpg
#   inflating: isic2020/train/ISIC_8600834.jpg
#   inflating: isic2020/train/ISIC_8601064.jpg
#   inflating: isic2020/train/ISIC_8601951.jpg
#   inflating: isic2020/train/ISIC_8602467.jpg
#   inflating: isic2020/train/ISIC_8603054.jpg
#   inflating: isic2020/train/ISIC_8603087.jpg
#   inflating: isic2020/train/ISIC_8603124.jpg
#   inflating: isic2020/train/ISIC_8603396.jpg
#   inflating: isic2020/train/ISIC_8603493.jpg
#   inflating: isic2020/train/ISIC_8603567.jpg
#   inflating: isic2020/train/ISIC_8603734.jpg
#   inflating: isic2020/train/ISIC_8604565.jpg
#   inflating: isic2020/train/ISIC_8604922.jpg
#   inflating: isic2020/train/ISIC_8605191.jpg
#   inflating: isic2020/train/ISIC_8605422.jpg
#   inflating: isic2020/train/ISIC_8605941.jpg
#   inflating: isic2020/train/ISIC_8606094.jpg
#   inflating: isic2020/train/ISIC_8606969.jpg
#   inflating: isic2020/train/ISIC_8607090.jpg
#   inflating: isic2020/train/ISIC_8607298.jpg
#   inflating: isic2020/train/ISIC_8607372.jpg
#   inflating: isic2020/train/ISIC_8608062.jpg
#   inflating: isic2020/train/ISIC_8608270.jpg
#   inflating: isic2020/train/ISIC_8608794.jpg
#   inflating: isic2020/train/ISIC_8608894.jpg
#   inflating: isic2020/train/ISIC_8609722.jpg
#   inflating: isic2020/train/ISIC_8609756.jpg
#   inflating: isic2020/train/ISIC_8609917.jpg
#   inflating: isic2020/train/ISIC_8610377.jpg
#   inflating: isic2020/train/ISIC_8610534.jpg
#   inflating: isic2020/train/ISIC_8611499.jpg
#   inflating: isic2020/train/ISIC_8611845.jpg
#   inflating: isic2020/train/ISIC_8612113.jpg
#   inflating: isic2020/train/ISIC_8612422.jpg
#   inflating: isic2020/train/ISIC_8612828.jpg
#   inflating: isic2020/train/ISIC_8612888.jpg
#   inflating: isic2020/train/ISIC_8613613.jpg
#   inflating: isic2020/train/ISIC_8613657.jpg
#   inflating: isic2020/train/ISIC_8614359.jpg
#   inflating: isic2020/train/ISIC_8614712.jpg
#   inflating: isic2020/train/ISIC_8614778.jpg
#   inflating: isic2020/train/ISIC_8614812.jpg
#   inflating: isic2020/train/ISIC_8615081.jpg
#   inflating: isic2020/train/ISIC_8615491.jpg
#   inflating: isic2020/train/ISIC_8616723.jpg
#   inflating: isic2020/train/ISIC_8617084.jpg
#   inflating: isic2020/train/ISIC_8617145.jpg
#   inflating: isic2020/train/ISIC_8617277.jpg
#   inflating: isic2020/train/ISIC_8617532.jpg
#   inflating: isic2020/train/ISIC_8618156.jpg
#   inflating: isic2020/train/ISIC_8618260.jpg
#   inflating: isic2020/train/ISIC_8618266.jpg
#   inflating: isic2020/train/ISIC_8618470.jpg
#   inflating: isic2020/train/ISIC_8618835.jpg
#   inflating: isic2020/train/ISIC_8619693.jpg
#   inflating: isic2020/train/ISIC_8620064.jpg
#   inflating: isic2020/train/ISIC_8620514.jpg
#   inflating: isic2020/train/ISIC_8621002.jpg
#   inflating: isic2020/train/ISIC_8621568.jpg
#   inflating: isic2020/train/ISIC_8621723.jpg
#   inflating: isic2020/train/ISIC_8621810.jpg
#   inflating: isic2020/train/ISIC_8622070.jpg
#   inflating: isic2020/train/ISIC_8622204.jpg
#   inflating: isic2020/train/ISIC_8622365.jpg
#   inflating: isic2020/train/ISIC_8622941.jpg
#   inflating: isic2020/train/ISIC_8623233.jpg
#   inflating: isic2020/train/ISIC_8623287.jpg
#   inflating: isic2020/train/ISIC_8623291.jpg
#   inflating: isic2020/train/ISIC_8623419.jpg
#   inflating: isic2020/train/ISIC_8623743.jpg
#   inflating: isic2020/train/ISIC_8624063.jpg
#   inflating: isic2020/train/ISIC_8624123.jpg
#   inflating: isic2020/train/ISIC_8624186.jpg
#   inflating: isic2020/train/ISIC_8624230.jpg
#   inflating: isic2020/train/ISIC_8624783.jpg
#   inflating: isic2020/train/ISIC_8626005.jpg
#   inflating: isic2020/train/ISIC_8626042.jpg
#   inflating: isic2020/train/ISIC_8626627.jpg
#   inflating: isic2020/train/ISIC_8626787.jpg
#   inflating: isic2020/train/ISIC_8626909.jpg
#   inflating: isic2020/train/ISIC_8626941.jpg
#   inflating: isic2020/train/ISIC_8626997.jpg
#   inflating: isic2020/train/ISIC_8627293.jpg
#   inflating: isic2020/train/ISIC_8628166.jpg
#   inflating: isic2020/train/ISIC_8628207.jpg
#   inflating: isic2020/train/ISIC_8628639.jpg
#   inflating: isic2020/train/ISIC_8628723.jpg
#   inflating: isic2020/train/ISIC_8628846.jpg
#   inflating: isic2020/train/ISIC_8629084.jpg
#   inflating: isic2020/train/ISIC_8629308.jpg
#   inflating: isic2020/train/ISIC_8629489.jpg
#   inflating: isic2020/train/ISIC_8629635.jpg
#   inflating: isic2020/train/ISIC_8629649.jpg
#   inflating: isic2020/train/ISIC_8629932.jpg
#   inflating: isic2020/train/ISIC_8629973.jpg
#   inflating: isic2020/train/ISIC_8630008.jpg
#   inflating: isic2020/train/ISIC_8630053.jpg
#   inflating: isic2020/train/ISIC_8630300.jpg
#   inflating: isic2020/train/ISIC_8630818.jpg
#   inflating: isic2020/train/ISIC_8630963.jpg
#   inflating: isic2020/train/ISIC_8631304.jpg
#   inflating: isic2020/train/ISIC_8631846.jpg
#   inflating: isic2020/train/ISIC_8632147.jpg
#   inflating: isic2020/train/ISIC_8632184.jpg
#   inflating: isic2020/train/ISIC_8632387.jpg
#   inflating: isic2020/train/ISIC_8632610.jpg
#   inflating: isic2020/train/ISIC_8632694.jpg
#   inflating: isic2020/train/ISIC_8632929.jpg
#   inflating: isic2020/train/ISIC_8633132.jpg
#   inflating: isic2020/train/ISIC_8633166.jpg
#   inflating: isic2020/train/ISIC_8633512.jpg
#   inflating: isic2020/train/ISIC_8633719.jpg
#   inflating: isic2020/train/ISIC_8633889.jpg
#   inflating: isic2020/train/ISIC_8633894.jpg
#   inflating: isic2020/train/ISIC_8634022.jpg
#   inflating: isic2020/train/ISIC_8634334.jpg
#   inflating: isic2020/train/ISIC_8634356.jpg
#   inflating: isic2020/train/ISIC_8634670.jpg
#   inflating: isic2020/train/ISIC_8634832.jpg
#   inflating: isic2020/train/ISIC_8635020.jpg
#   inflating: isic2020/train/ISIC_8635849.jpg
#   inflating: isic2020/train/ISIC_8635853.jpg
#   inflating: isic2020/train/ISIC_8635889.jpg
#   inflating: isic2020/train/ISIC_8635903.jpg
#   inflating: isic2020/train/ISIC_8636548.jpg
#   inflating: isic2020/train/ISIC_8636598.jpg
#   inflating: isic2020/train/ISIC_8636695.jpg
#   inflating: isic2020/train/ISIC_8636706.jpg
#   inflating: isic2020/train/ISIC_8636868.jpg
#   inflating: isic2020/train/ISIC_8637134.jpg
#   inflating: isic2020/train/ISIC_8637235.jpg
#   inflating: isic2020/train/ISIC_8637407.jpg
#   inflating: isic2020/train/ISIC_8638021.jpg
#   inflating: isic2020/train/ISIC_8638173.jpg
#   inflating: isic2020/train/ISIC_8639128.jpg
#   inflating: isic2020/train/ISIC_8639448.jpg
#   inflating: isic2020/train/ISIC_8639491.jpg
#   inflating: isic2020/train/ISIC_8639771.jpg
#   inflating: isic2020/train/ISIC_8641048.jpg
#   inflating: isic2020/train/ISIC_8641628.jpg
#   inflating: isic2020/train/ISIC_8642670.jpg
#   inflating: isic2020/train/ISIC_8642938.jpg
#   inflating: isic2020/train/ISIC_8643364.jpg
#   inflating: isic2020/train/ISIC_8643675.jpg
#   inflating: isic2020/train/ISIC_8644092.jpg
#   inflating: isic2020/train/ISIC_8645104.jpg
#   inflating: isic2020/train/ISIC_8645633.jpg
#   inflating: isic2020/train/ISIC_8646115.jpg
#   inflating: isic2020/train/ISIC_8646276.jpg
#   inflating: isic2020/train/ISIC_8647135.jpg
#   inflating: isic2020/train/ISIC_8647334.jpg
#   inflating: isic2020/train/ISIC_8647900.jpg
#   inflating: isic2020/train/ISIC_8648090.jpg
#   inflating: isic2020/train/ISIC_8648359.jpg
#   inflating: isic2020/train/ISIC_8648734.jpg
#   inflating: isic2020/train/ISIC_8649055.jpg
#   inflating: isic2020/train/ISIC_8649251.jpg
#   inflating: isic2020/train/ISIC_8649964.jpg
#   inflating: isic2020/train/ISIC_8650269.jpg
#   inflating: isic2020/train/ISIC_8650478.jpg
#   inflating: isic2020/train/ISIC_8650516.jpg
#   inflating: isic2020/train/ISIC_8651053.jpg
#   inflating: isic2020/train/ISIC_8651078.jpg
#   inflating: isic2020/train/ISIC_8651476.jpg
#   inflating: isic2020/train/ISIC_8651541.jpg
#   inflating: isic2020/train/ISIC_8651765.jpg
#   inflating: isic2020/train/ISIC_8651863.jpg
#   inflating: isic2020/train/ISIC_8652341.jpg
#   inflating: isic2020/train/ISIC_8652599.jpg
#   inflating: isic2020/train/ISIC_8652894.jpg
#   inflating: isic2020/train/ISIC_8653009.jpg
#   inflating: isic2020/train/ISIC_8653749.jpg
#   inflating: isic2020/train/ISIC_8653813.jpg
#   inflating: isic2020/train/ISIC_8653964.jpg
#   inflating: isic2020/train/ISIC_8654113.jpg
#   inflating: isic2020/train/ISIC_8654312.jpg
#   inflating: isic2020/train/ISIC_8654660.jpg
#   inflating: isic2020/train/ISIC_8655206.jpg
#   inflating: isic2020/train/ISIC_8655308.jpg
#   inflating: isic2020/train/ISIC_8655438.jpg
#   inflating: isic2020/train/ISIC_8655487.jpg
#   inflating: isic2020/train/ISIC_8655912.jpg
#   inflating: isic2020/train/ISIC_8656006.jpg
#   inflating: isic2020/train/ISIC_8656015.jpg
#   inflating: isic2020/train/ISIC_8656760.jpg
#   inflating: isic2020/train/ISIC_8657028.jpg
#   inflating: isic2020/train/ISIC_8657064.jpg
#   inflating: isic2020/train/ISIC_8657079.jpg
#   inflating: isic2020/train/ISIC_8657132.jpg
#   inflating: isic2020/train/ISIC_8657243.jpg
#   inflating: isic2020/train/ISIC_8657381.jpg
#   inflating: isic2020/train/ISIC_8657895.jpg
#   inflating: isic2020/train/ISIC_8658037.jpg
#   inflating: isic2020/train/ISIC_8658618.jpg
#   inflating: isic2020/train/ISIC_8658889.jpg
#   inflating: isic2020/train/ISIC_8659007.jpg
#   inflating: isic2020/train/ISIC_8659065.jpg
#   inflating: isic2020/train/ISIC_8659272.jpg
#   inflating: isic2020/train/ISIC_8659425.jpg
#   inflating: isic2020/train/ISIC_8659461.jpg
#   inflating: isic2020/train/ISIC_8659618.jpg
#   inflating: isic2020/train/ISIC_8659639.jpg
#   inflating: isic2020/train/ISIC_8659694.jpg
#   inflating: isic2020/train/ISIC_8660448.jpg
#   inflating: isic2020/train/ISIC_8660830.jpg
#   inflating: isic2020/train/ISIC_8661039.jpg
#   inflating: isic2020/train/ISIC_8661226.jpg
#   inflating: isic2020/train/ISIC_8661536.jpg
#   inflating: isic2020/train/ISIC_8661993.jpg
#   inflating: isic2020/train/ISIC_8662655.jpg
#   inflating: isic2020/train/ISIC_8662707.jpg
#   inflating: isic2020/train/ISIC_8663136.jpg
#   inflating: isic2020/train/ISIC_8663291.jpg
#   inflating: isic2020/train/ISIC_8663353.jpg
#   inflating: isic2020/train/ISIC_8663681.jpg
#   inflating: isic2020/train/ISIC_8663746.jpg
#   inflating: isic2020/train/ISIC_8663920.jpg
#   inflating: isic2020/train/ISIC_8663971.jpg
#   inflating: isic2020/train/ISIC_8664196.jpg
#   inflating: isic2020/train/ISIC_8664315.jpg
#   inflating: isic2020/train/ISIC_8664718.jpg
#   inflating: isic2020/train/ISIC_8664819.jpg
#   inflating: isic2020/train/ISIC_8665109.jpg
#   inflating: isic2020/train/ISIC_8666405.jpg
#   inflating: isic2020/train/ISIC_8666446.jpg
#   inflating: isic2020/train/ISIC_8666637.jpg
#   inflating: isic2020/train/ISIC_8667319.jpg
#   inflating: isic2020/train/ISIC_8667460.jpg
#   inflating: isic2020/train/ISIC_8667552.jpg
#   inflating: isic2020/train/ISIC_8667588.jpg
#   inflating: isic2020/train/ISIC_8667613.jpg
#   inflating: isic2020/train/ISIC_8667653.jpg
#   inflating: isic2020/train/ISIC_8667793.jpg
#   inflating: isic2020/train/ISIC_8668283.jpg
#   inflating: isic2020/train/ISIC_8668448.jpg
#   inflating: isic2020/train/ISIC_8668530.jpg
#   inflating: isic2020/train/ISIC_8668631.jpg
#   inflating: isic2020/train/ISIC_8668954.jpg
#   inflating: isic2020/train/ISIC_8669004.jpg
#   inflating: isic2020/train/ISIC_8669067.jpg
#   inflating: isic2020/train/ISIC_8669314.jpg
#   inflating: isic2020/train/ISIC_8669560.jpg
#   inflating: isic2020/train/ISIC_8669968.jpg
#   inflating: isic2020/train/ISIC_8669989.jpg
#   inflating: isic2020/train/ISIC_8670080.jpg
#   inflating: isic2020/train/ISIC_8670418.jpg
#   inflating: isic2020/train/ISIC_8670477.jpg
#   inflating: isic2020/train/ISIC_8670684.jpg
#   inflating: isic2020/train/ISIC_8670789.jpg
#   inflating: isic2020/train/ISIC_8671412.jpg
#   inflating: isic2020/train/ISIC_8671453.jpg
#   inflating: isic2020/train/ISIC_8671662.jpg
#   inflating: isic2020/train/ISIC_8671702.jpg
#   inflating: isic2020/train/ISIC_8672185.jpg
#   inflating: isic2020/train/ISIC_8672524.jpg
#   inflating: isic2020/train/ISIC_8672553.jpg
#   inflating: isic2020/train/ISIC_8673238.jpg
#   inflating: isic2020/train/ISIC_8674332.jpg
#   inflating: isic2020/train/ISIC_8674558.jpg
#   inflating: isic2020/train/ISIC_8674937.jpg
#   inflating: isic2020/train/ISIC_8675105.jpg
#   inflating: isic2020/train/ISIC_8675233.jpg
#   inflating: isic2020/train/ISIC_8675566.jpg
#   inflating: isic2020/train/ISIC_8675583.jpg
#   inflating: isic2020/train/ISIC_8675695.jpg
#   inflating: isic2020/train/ISIC_8676305.jpg
#   inflating: isic2020/train/ISIC_8676418.jpg
#   inflating: isic2020/train/ISIC_8676622.jpg
#   inflating: isic2020/train/ISIC_8677053.jpg
#   inflating: isic2020/train/ISIC_8677110.jpg
#   inflating: isic2020/train/ISIC_8677254.jpg
#   inflating: isic2020/train/ISIC_8677503.jpg
#   inflating: isic2020/train/ISIC_8678163.jpg
#   inflating: isic2020/train/ISIC_8678440.jpg
#   inflating: isic2020/train/ISIC_8679067.jpg
#   inflating: isic2020/train/ISIC_8679149.jpg
#   inflating: isic2020/train/ISIC_8679397.jpg
#   inflating: isic2020/train/ISIC_8679617.jpg
#   inflating: isic2020/train/ISIC_8679740.jpg
#   inflating: isic2020/train/ISIC_8680191.jpg
#   inflating: isic2020/train/ISIC_8680204.jpg
#   inflating: isic2020/train/ISIC_8680266.jpg
#   inflating: isic2020/train/ISIC_8680421.jpg
#   inflating: isic2020/train/ISIC_8680948.jpg
#   inflating: isic2020/train/ISIC_8681290.jpg
#   inflating: isic2020/train/ISIC_8681540.jpg
#   inflating: isic2020/train/ISIC_8681838.jpg
#   inflating: isic2020/train/ISIC_8681917.jpg
#   inflating: isic2020/train/ISIC_8683098.jpg
#   inflating: isic2020/train/ISIC_8684147.jpg
#   inflating: isic2020/train/ISIC_8685259.jpg
#   inflating: isic2020/train/ISIC_8685266.jpg
#   inflating: isic2020/train/ISIC_8686097.jpg
#   inflating: isic2020/train/ISIC_8686253.jpg
#   inflating: isic2020/train/ISIC_8686847.jpg
#   inflating: isic2020/train/ISIC_8686962.jpg
#   inflating: isic2020/train/ISIC_8687105.jpg
#   inflating: isic2020/train/ISIC_8687356.jpg
#   inflating: isic2020/train/ISIC_8689112.jpg
#   inflating: isic2020/train/ISIC_8689144.jpg
#   inflating: isic2020/train/ISIC_8689284.jpg
#   inflating: isic2020/train/ISIC_8689532.jpg
#   inflating: isic2020/train/ISIC_8689583.jpg
#   inflating: isic2020/train/ISIC_8689811.jpg
#   inflating: isic2020/train/ISIC_8690205.jpg
#   inflating: isic2020/train/ISIC_8690232.jpg
#   inflating: isic2020/train/ISIC_8690631.jpg
#   inflating: isic2020/train/ISIC_8690825.jpg
#   inflating: isic2020/train/ISIC_8691091.jpg
#   inflating: isic2020/train/ISIC_8691163.jpg
#   inflating: isic2020/train/ISIC_8691327.jpg
#   inflating: isic2020/train/ISIC_8691891.jpg
#   inflating: isic2020/train/ISIC_8692006.jpg
#   inflating: isic2020/train/ISIC_8692064.jpg
#   inflating: isic2020/train/ISIC_8692155.jpg
#   inflating: isic2020/train/ISIC_8692218.jpg
#   inflating: isic2020/train/ISIC_8692556.jpg
#   inflating: isic2020/train/ISIC_8692572.jpg
#   inflating: isic2020/train/ISIC_8692634.jpg
#   inflating: isic2020/train/ISIC_8692950.jpg
#   inflating: isic2020/train/ISIC_8693637.jpg
#   inflating: isic2020/train/ISIC_8693823.jpg
#   inflating: isic2020/train/ISIC_8693856.jpg
#   inflating: isic2020/train/ISIC_8694181.jpg
#   inflating: isic2020/train/ISIC_8694800.jpg
#   inflating: isic2020/train/ISIC_8694888.jpg
#   inflating: isic2020/train/ISIC_8695109.jpg
#   inflating: isic2020/train/ISIC_8695278.jpg
#   inflating: isic2020/train/ISIC_8695317.jpg
#   inflating: isic2020/train/ISIC_8696075.jpg
#   inflating: isic2020/train/ISIC_8696503.jpg
#   inflating: isic2020/train/ISIC_8696711.jpg
#   inflating: isic2020/train/ISIC_8697410.jpg
#   inflating: isic2020/train/ISIC_8697426.jpg
#   inflating: isic2020/train/ISIC_8698452.jpg
#   inflating: isic2020/train/ISIC_8698578.jpg
#   inflating: isic2020/train/ISIC_8699105.jpg
#   inflating: isic2020/train/ISIC_8699205.jpg
#   inflating: isic2020/train/ISIC_8699453.jpg
#   inflating: isic2020/train/ISIC_8699796.jpg
#   inflating: isic2020/train/ISIC_8699846.jpg
#   inflating: isic2020/train/ISIC_8700156.jpg
#   inflating: isic2020/train/ISIC_8700403.jpg
#   inflating: isic2020/train/ISIC_8700706.jpg
#   inflating: isic2020/train/ISIC_8700740.jpg
#   inflating: isic2020/train/ISIC_8700778.jpg
#   inflating: isic2020/train/ISIC_8701206.jpg
#   inflating: isic2020/train/ISIC_8701243.jpg
#   inflating: isic2020/train/ISIC_8701361.jpg
#   inflating: isic2020/train/ISIC_8701975.jpg
#   inflating: isic2020/train/ISIC_8702191.jpg
#   inflating: isic2020/train/ISIC_8702237.jpg
#   inflating: isic2020/train/ISIC_8702706.jpg
#   inflating: isic2020/train/ISIC_8703169.jpg
#   inflating: isic2020/train/ISIC_8703209.jpg
#   inflating: isic2020/train/ISIC_8703375.jpg
#   inflating: isic2020/train/ISIC_8704004.jpg
#   inflating: isic2020/train/ISIC_8704257.jpg
#   inflating: isic2020/train/ISIC_8704668.jpg
#   inflating: isic2020/train/ISIC_8704672.jpg
#   inflating: isic2020/train/ISIC_8704926.jpg
#   inflating: isic2020/train/ISIC_8705071.jpg
#   inflating: isic2020/train/ISIC_8705622.jpg
#   inflating: isic2020/train/ISIC_8705626.jpg
#   inflating: isic2020/train/ISIC_8705729.jpg
#   inflating: isic2020/train/ISIC_8705845.jpg
#   inflating: isic2020/train/ISIC_8706257.jpg
#   inflating: isic2020/train/ISIC_8706279.jpg
#   inflating: isic2020/train/ISIC_8706325.jpg
#   inflating: isic2020/train/ISIC_8706441.jpg
#   inflating: isic2020/train/ISIC_8706667.jpg
#   inflating: isic2020/train/ISIC_8706909.jpg
#   inflating: isic2020/train/ISIC_8707477.jpg
#   inflating: isic2020/train/ISIC_8707606.jpg
#   inflating: isic2020/train/ISIC_8707625.jpg
#   inflating: isic2020/train/ISIC_8708137.jpg
#   inflating: isic2020/train/ISIC_8708756.jpg
#   inflating: isic2020/train/ISIC_8708847.jpg
#   inflating: isic2020/train/ISIC_8709211.jpg
#   inflating: isic2020/train/ISIC_8709649.jpg
#   inflating: isic2020/train/ISIC_8709698.jpg
#   inflating: isic2020/train/ISIC_8710040.jpg
#   inflating: isic2020/train/ISIC_8710457.jpg
#   inflating: isic2020/train/ISIC_8710935.jpg
#   inflating: isic2020/train/ISIC_8711307.jpg
#   inflating: isic2020/train/ISIC_8711778.jpg
#   inflating: isic2020/train/ISIC_8711854.jpg
#   inflating: isic2020/train/ISIC_8711983.jpg
#   inflating: isic2020/train/ISIC_8712028.jpg
#   inflating: isic2020/train/ISIC_8712312.jpg
#   inflating: isic2020/train/ISIC_8712401.jpg
#   inflating: isic2020/train/ISIC_8712868.jpg
#   inflating: isic2020/train/ISIC_8712906.jpg
#   inflating: isic2020/train/ISIC_8712921.jpg
#   inflating: isic2020/train/ISIC_8712927.jpg
#   inflating: isic2020/train/ISIC_8712998.jpg
#   inflating: isic2020/train/ISIC_8713330.jpg
#   inflating: isic2020/train/ISIC_8713598.jpg
#   inflating: isic2020/train/ISIC_8714502.jpg
#   inflating: isic2020/train/ISIC_8714837.jpg
#   inflating: isic2020/train/ISIC_8715329.jpg
#   inflating: isic2020/train/ISIC_8715332.jpg
#   inflating: isic2020/train/ISIC_8715507.jpg
#   inflating: isic2020/train/ISIC_8715705.jpg
#   inflating: isic2020/train/ISIC_8715792.jpg
#   inflating: isic2020/train/ISIC_8716192.jpg
#   inflating: isic2020/train/ISIC_8716235.jpg
#   inflating: isic2020/train/ISIC_8716533.jpg
#   inflating: isic2020/train/ISIC_8716644.jpg
#   inflating: isic2020/train/ISIC_8717030.jpg
#   inflating: isic2020/train/ISIC_8717336.jpg
#   inflating: isic2020/train/ISIC_8717495.jpg
#   inflating: isic2020/train/ISIC_8718269.jpg
#   inflating: isic2020/train/ISIC_8719134.jpg
#   inflating: isic2020/train/ISIC_8719270.jpg
#   inflating: isic2020/train/ISIC_8719883.jpg
#   inflating: isic2020/train/ISIC_8719979.jpg
#   inflating: isic2020/train/ISIC_8720514.jpg
#   inflating: isic2020/train/ISIC_8721166.jpg
#   inflating: isic2020/train/ISIC_8721182.jpg
#   inflating: isic2020/train/ISIC_8722032.jpg
#   inflating: isic2020/train/ISIC_8722181.jpg
#   inflating: isic2020/train/ISIC_8722264.jpg
#   inflating: isic2020/train/ISIC_8722667.jpg
#   inflating: isic2020/train/ISIC_8723302.jpg
#   inflating: isic2020/train/ISIC_8723397.jpg
#   inflating: isic2020/train/ISIC_8723773.jpg
#   inflating: isic2020/train/ISIC_8723815.jpg
#   inflating: isic2020/train/ISIC_8724791.jpg
#   inflating: isic2020/train/ISIC_8724944.jpg
#   inflating: isic2020/train/ISIC_8725334.jpg
#   inflating: isic2020/train/ISIC_8725878.jpg
#   inflating: isic2020/train/ISIC_8725993.jpg
#   inflating: isic2020/train/ISIC_8726066.jpg
#   inflating: isic2020/train/ISIC_8726600.jpg
#   inflating: isic2020/train/ISIC_8726909.jpg
#   inflating: isic2020/train/ISIC_8726948.jpg
#   inflating: isic2020/train/ISIC_8727047.jpg
#   inflating: isic2020/train/ISIC_8727731.jpg
#   inflating: isic2020/train/ISIC_8727962.jpg
#   inflating: isic2020/train/ISIC_8728527.jpg
#   inflating: isic2020/train/ISIC_8729064.jpg
#   inflating: isic2020/train/ISIC_8729091.jpg
#   inflating: isic2020/train/ISIC_8729274.jpg
#   inflating: isic2020/train/ISIC_8730617.jpg
#   inflating: isic2020/train/ISIC_8730957.jpg
#   inflating: isic2020/train/ISIC_8731219.jpg
#   inflating: isic2020/train/ISIC_8731692.jpg
#   inflating: isic2020/train/ISIC_8731844.jpg
#   inflating: isic2020/train/ISIC_8732572.jpg
#   inflating: isic2020/train/ISIC_8732757.jpg
#   inflating: isic2020/train/ISIC_8733422.jpg
#   inflating: isic2020/train/ISIC_8733745.jpg
#   inflating: isic2020/train/ISIC_8734128.jpg
#   inflating: isic2020/train/ISIC_8735133.jpg
#   inflating: isic2020/train/ISIC_8736590.jpg
#   inflating: isic2020/train/ISIC_8737794.jpg
#   inflating: isic2020/train/ISIC_8737864.jpg
#   inflating: isic2020/train/ISIC_8738168.jpg
#   inflating: isic2020/train/ISIC_8738598.jpg
#   inflating: isic2020/train/ISIC_8738797.jpg
#   inflating: isic2020/train/ISIC_8738925.jpg
#   inflating: isic2020/train/ISIC_8739046.jpg
#   inflating: isic2020/train/ISIC_8739231.jpg
#   inflating: isic2020/train/ISIC_8739533.jpg
#   inflating: isic2020/train/ISIC_8739762.jpg
#   inflating: isic2020/train/ISIC_8740331.jpg
#   inflating: isic2020/train/ISIC_8740452.jpg
#   inflating: isic2020/train/ISIC_8740548.jpg
#   inflating: isic2020/train/ISIC_8740695.jpg
#   inflating: isic2020/train/ISIC_8741533.jpg
#   inflating: isic2020/train/ISIC_8741594.jpg
#   inflating: isic2020/train/ISIC_8741881.jpg
#   inflating: isic2020/train/ISIC_8742034.jpg
#   inflating: isic2020/train/ISIC_8742277.jpg
#   inflating: isic2020/train/ISIC_8742407.jpg
#   inflating: isic2020/train/ISIC_8742875.jpg
#   inflating: isic2020/train/ISIC_8742972.jpg
#   inflating: isic2020/train/ISIC_8743583.jpg
#   inflating: isic2020/train/ISIC_8744681.jpg
#   inflating: isic2020/train/ISIC_8745294.jpg
#   inflating: isic2020/train/ISIC_8745884.jpg
#   inflating: isic2020/train/ISIC_8746257.jpg
#   inflating: isic2020/train/ISIC_8746756.jpg
#   inflating: isic2020/train/ISIC_8746871.jpg
#   inflating: isic2020/train/ISIC_8747095.jpg
#   inflating: isic2020/train/ISIC_8747149.jpg
#   inflating: isic2020/train/ISIC_8747435.jpg
#   inflating: isic2020/train/ISIC_8747441.jpg
#   inflating: isic2020/train/ISIC_8748070.jpg
#   inflating: isic2020/train/ISIC_8748253.jpg
#   inflating: isic2020/train/ISIC_8748689.jpg
#   inflating: isic2020/train/ISIC_8748711.jpg
#   inflating: isic2020/train/ISIC_8748953.jpg
#   inflating: isic2020/train/ISIC_8749288.jpg
#   inflating: isic2020/train/ISIC_8749666.jpg
#   inflating: isic2020/train/ISIC_8749680.jpg
#   inflating: isic2020/train/ISIC_8750055.jpg
#   inflating: isic2020/train/ISIC_8750103.jpg
#   inflating: isic2020/train/ISIC_8750167.jpg
#   inflating: isic2020/train/ISIC_8750509.jpg
#   inflating: isic2020/train/ISIC_8750635.jpg
#   inflating: isic2020/train/ISIC_8750920.jpg
#   inflating: isic2020/train/ISIC_8751042.jpg
#   inflating: isic2020/train/ISIC_8751106.jpg
#   inflating: isic2020/train/ISIC_8751380.jpg
#   inflating: isic2020/train/ISIC_8751393.jpg
#   inflating: isic2020/train/ISIC_8751661.jpg
#   inflating: isic2020/train/ISIC_8753151.jpg
#   inflating: isic2020/train/ISIC_8753831.jpg
#   inflating: isic2020/train/ISIC_8754461.jpg
#   inflating: isic2020/train/ISIC_8754527.jpg
#   inflating: isic2020/train/ISIC_8754690.jpg
#   inflating: isic2020/train/ISIC_8754972.jpg
#   inflating: isic2020/train/ISIC_8755163.jpg
#   inflating: isic2020/train/ISIC_8755239.jpg
#   inflating: isic2020/train/ISIC_8755312.jpg
#   inflating: isic2020/train/ISIC_8755605.jpg
#   inflating: isic2020/train/ISIC_8755714.jpg
#   inflating: isic2020/train/ISIC_8755969.jpg
#   inflating: isic2020/train/ISIC_8756011.jpg
#   inflating: isic2020/train/ISIC_8756356.jpg
#   inflating: isic2020/train/ISIC_8757180.jpg
#   inflating: isic2020/train/ISIC_8757204.jpg
#   inflating: isic2020/train/ISIC_8757263.jpg
#   inflating: isic2020/train/ISIC_8757664.jpg
#   inflating: isic2020/train/ISIC_8758359.jpg
#   inflating: isic2020/train/ISIC_8758601.jpg
#   inflating: isic2020/train/ISIC_8758801.jpg
#   inflating: isic2020/train/ISIC_8758963.jpg
#   inflating: isic2020/train/ISIC_8759073.jpg
#   inflating: isic2020/train/ISIC_8759207.jpg
#   inflating: isic2020/train/ISIC_8759726.jpg
#   inflating: isic2020/train/ISIC_8759744.jpg
#   inflating: isic2020/train/ISIC_8759813.jpg
#   inflating: isic2020/train/ISIC_8759880.jpg
#   inflating: isic2020/train/ISIC_8760029.jpg
#   inflating: isic2020/train/ISIC_8760379.jpg
#   inflating: isic2020/train/ISIC_8760380.jpg
#   inflating: isic2020/train/ISIC_8760731.jpg
#   inflating: isic2020/train/ISIC_8761972.jpg
#   inflating: isic2020/train/ISIC_8762217.jpg
#   inflating: isic2020/train/ISIC_8762368.jpg
#   inflating: isic2020/train/ISIC_8762437.jpg
#   inflating: isic2020/train/ISIC_8763099.jpg
#   inflating: isic2020/train/ISIC_8764094.jpg
#   inflating: isic2020/train/ISIC_8764200.jpg
#   inflating: isic2020/train/ISIC_8764217.jpg
#   inflating: isic2020/train/ISIC_8764464.jpg
#   inflating: isic2020/train/ISIC_8764927.jpg
#   inflating: isic2020/train/ISIC_8765068.jpg
#   inflating: isic2020/train/ISIC_8765435.jpg
#   inflating: isic2020/train/ISIC_8766132.jpg
#   inflating: isic2020/train/ISIC_8766254.jpg
#   inflating: isic2020/train/ISIC_8766644.jpg
#   inflating: isic2020/train/ISIC_8766977.jpg
#   inflating: isic2020/train/ISIC_8767074.jpg
#   inflating: isic2020/train/ISIC_8767759.jpg
#   inflating: isic2020/train/ISIC_8768354.jpg
#   inflating: isic2020/train/ISIC_8769391.jpg
#   inflating: isic2020/train/ISIC_8769415.jpg
#   inflating: isic2020/train/ISIC_8770180.jpg
#   inflating: isic2020/train/ISIC_8770205.jpg
#   inflating: isic2020/train/ISIC_8770401.jpg
#   inflating: isic2020/train/ISIC_8771426.jpg
#   inflating: isic2020/train/ISIC_8771892.jpg
#   inflating: isic2020/train/ISIC_8772062.jpg
#   inflating: isic2020/train/ISIC_8772124.jpg
#   inflating: isic2020/train/ISIC_8772177.jpg
#   inflating: isic2020/train/ISIC_8772241.jpg
#   inflating: isic2020/train/ISIC_8772377.jpg
#   inflating: isic2020/train/ISIC_8772811.jpg
#   inflating: isic2020/train/ISIC_8772865.jpg
#   inflating: isic2020/train/ISIC_8773478.jpg
#   inflating: isic2020/train/ISIC_8773568.jpg
#   inflating: isic2020/train/ISIC_8773685.jpg
#   inflating: isic2020/train/ISIC_8773962.jpg
#   inflating: isic2020/train/ISIC_8774086.jpg
#   inflating: isic2020/train/ISIC_8774326.jpg
#   inflating: isic2020/train/ISIC_8774880.jpg
#   inflating: isic2020/train/ISIC_8775014.jpg
#   inflating: isic2020/train/ISIC_8775181.jpg
#   inflating: isic2020/train/ISIC_8775575.jpg
#   inflating: isic2020/train/ISIC_8775674.jpg
#   inflating: isic2020/train/ISIC_8776363.jpg
#   inflating: isic2020/train/ISIC_8776630.jpg
#   inflating: isic2020/train/ISIC_8776646.jpg
#   inflating: isic2020/train/ISIC_8776661.jpg
#   inflating: isic2020/train/ISIC_8776686.jpg
#   inflating: isic2020/train/ISIC_8776941.jpg
#   inflating: isic2020/train/ISIC_8777622.jpg
#   inflating: isic2020/train/ISIC_8777813.jpg
#   inflating: isic2020/train/ISIC_8777856.jpg
#   inflating: isic2020/train/ISIC_8777866.jpg
#   inflating: isic2020/train/ISIC_8778158.jpg
#   inflating: isic2020/train/ISIC_8778303.jpg
#   inflating: isic2020/train/ISIC_8778648.jpg
#   inflating: isic2020/train/ISIC_8779013.jpg
#   inflating: isic2020/train/ISIC_8779142.jpg
#   inflating: isic2020/train/ISIC_8779202.jpg
#   inflating: isic2020/train/ISIC_8779825.jpg
#   inflating: isic2020/train/ISIC_8780369.jpg
#   inflating: isic2020/train/ISIC_8780547.jpg
#   inflating: isic2020/train/ISIC_8781050.jpg
#   inflating: isic2020/train/ISIC_8781281.jpg
#   inflating: isic2020/train/ISIC_8781377.jpg
#   inflating: isic2020/train/ISIC_8781451.jpg
#   inflating: isic2020/train/ISIC_8781751.jpg
#   inflating: isic2020/train/ISIC_8782134.jpg
#   inflating: isic2020/train/ISIC_8782612.jpg
#   inflating: isic2020/train/ISIC_8782954.jpg
#   inflating: isic2020/train/ISIC_8783000.jpg
#   inflating: isic2020/train/ISIC_8783066.jpg
#   inflating: isic2020/train/ISIC_8783667.jpg
#   inflating: isic2020/train/ISIC_8784687.jpg
#   inflating: isic2020/train/ISIC_8785329.jpg
#   inflating: isic2020/train/ISIC_8785434.jpg
#   inflating: isic2020/train/ISIC_8785777.jpg
#   inflating: isic2020/train/ISIC_8786539.jpg
#   inflating: isic2020/train/ISIC_8786606.jpg
#   inflating: isic2020/train/ISIC_8786693.jpg
#   inflating: isic2020/train/ISIC_8787152.jpg
#   inflating: isic2020/train/ISIC_8787622.jpg
#   inflating: isic2020/train/ISIC_8787826.jpg
#   inflating: isic2020/train/ISIC_8788485.jpg
#   inflating: isic2020/train/ISIC_8789051.jpg
#   inflating: isic2020/train/ISIC_8789373.jpg
#   inflating: isic2020/train/ISIC_8789673.jpg
#   inflating: isic2020/train/ISIC_8790198.jpg
#   inflating: isic2020/train/ISIC_8790201.jpg
#   inflating: isic2020/train/ISIC_8790582.jpg
#   inflating: isic2020/train/ISIC_8790659.jpg
#   inflating: isic2020/train/ISIC_8790885.jpg
#   inflating: isic2020/train/ISIC_8791163.jpg
#   inflating: isic2020/train/ISIC_8791321.jpg
#   inflating: isic2020/train/ISIC_8791385.jpg
#   inflating: isic2020/train/ISIC_8791493.jpg
#   inflating: isic2020/train/ISIC_8791603.jpg
#   inflating: isic2020/train/ISIC_8791729.jpg
#   inflating: isic2020/train/ISIC_8791744.jpg
#   inflating: isic2020/train/ISIC_8792007.jpg
#   inflating: isic2020/train/ISIC_8792040.jpg
#   inflating: isic2020/train/ISIC_8792193.jpg
#   inflating: isic2020/train/ISIC_8793471.jpg
#   inflating: isic2020/train/ISIC_8793609.jpg
#   inflating: isic2020/train/ISIC_8794221.jpg
#   inflating: isic2020/train/ISIC_8794314.jpg
#   inflating: isic2020/train/ISIC_8794567.jpg
#   inflating: isic2020/train/ISIC_8794796.jpg
#   inflating: isic2020/train/ISIC_8794882.jpg
#   inflating: isic2020/train/ISIC_8794948.jpg
#   inflating: isic2020/train/ISIC_8795038.jpg
#   inflating: isic2020/train/ISIC_8795435.jpg
#   inflating: isic2020/train/ISIC_8795740.jpg
#   inflating: isic2020/train/ISIC_8795968.jpg
#   inflating: isic2020/train/ISIC_8796413.jpg
#   inflating: isic2020/train/ISIC_8796456.jpg
#   inflating: isic2020/train/ISIC_8796632.jpg
#   inflating: isic2020/train/ISIC_8796654.jpg
#   inflating: isic2020/train/ISIC_8796769.jpg
#   inflating: isic2020/train/ISIC_8796968.jpg
#   inflating: isic2020/train/ISIC_8797277.jpg
#   inflating: isic2020/train/ISIC_8797868.jpg
#   inflating: isic2020/train/ISIC_8798059.jpg
#   inflating: isic2020/train/ISIC_8798119.jpg
#   inflating: isic2020/train/ISIC_8798305.jpg
#   inflating: isic2020/train/ISIC_8798346.jpg
#   inflating: isic2020/train/ISIC_8798579.jpg
#   inflating: isic2020/train/ISIC_8798839.jpg
#   inflating: isic2020/train/ISIC_8799089.jpg
#   inflating: isic2020/train/ISIC_8799158.jpg
#   inflating: isic2020/train/ISIC_8799470.jpg
#   inflating: isic2020/train/ISIC_8799512.jpg
#   inflating: isic2020/train/ISIC_8799674.jpg
#   inflating: isic2020/train/ISIC_8799844.jpg
#   inflating: isic2020/train/ISIC_8800200.jpg
#   inflating: isic2020/train/ISIC_8802047.jpg
#   inflating: isic2020/train/ISIC_8802544.jpg
#   inflating: isic2020/train/ISIC_8802922.jpg
#   inflating: isic2020/train/ISIC_8803537.jpg
#   inflating: isic2020/train/ISIC_8803600.jpg
#   inflating: isic2020/train/ISIC_8803795.jpg
#   inflating: isic2020/train/ISIC_8804009.jpg
#   inflating: isic2020/train/ISIC_8804606.jpg
#   inflating: isic2020/train/ISIC_8804704.jpg
#   inflating: isic2020/train/ISIC_8805000.jpg
#   inflating: isic2020/train/ISIC_8805114.jpg
#   inflating: isic2020/train/ISIC_8805730.jpg
#   inflating: isic2020/train/ISIC_8806090.jpg
#   inflating: isic2020/train/ISIC_8806180.jpg
#   inflating: isic2020/train/ISIC_8806357.jpg
#   inflating: isic2020/train/ISIC_8806519.jpg
#   inflating: isic2020/train/ISIC_8806647.jpg
#   inflating: isic2020/train/ISIC_8806941.jpg
#   inflating: isic2020/train/ISIC_8807058.jpg
#   inflating: isic2020/train/ISIC_8808006.jpg
#   inflating: isic2020/train/ISIC_8808627.jpg
#   inflating: isic2020/train/ISIC_8808683.jpg
#   inflating: isic2020/train/ISIC_8808756.jpg
#   inflating: isic2020/train/ISIC_8808909.jpg
#   inflating: isic2020/train/ISIC_8809618.jpg
#   inflating: isic2020/train/ISIC_8809821.jpg
#   inflating: isic2020/train/ISIC_8811120.jpg
#   inflating: isic2020/train/ISIC_8811316.jpg
#   inflating: isic2020/train/ISIC_8811596.jpg
#   inflating: isic2020/train/ISIC_8812186.jpg
#   inflating: isic2020/train/ISIC_8812621.jpg
#   inflating: isic2020/train/ISIC_8812739.jpg
#   inflating: isic2020/train/ISIC_8812781.jpg
#   inflating: isic2020/train/ISIC_8812830.jpg
#   inflating: isic2020/train/ISIC_8813040.jpg
#   inflating: isic2020/train/ISIC_8813078.jpg
#   inflating: isic2020/train/ISIC_8813283.jpg
#   inflating: isic2020/train/ISIC_8813303.jpg
#   inflating: isic2020/train/ISIC_8813306.jpg
#   inflating: isic2020/train/ISIC_8813415.jpg
#   inflating: isic2020/train/ISIC_8813838.jpg
#   inflating: isic2020/train/ISIC_8814398.jpg
#   inflating: isic2020/train/ISIC_8814507.jpg
#   inflating: isic2020/train/ISIC_8814612.jpg
#   inflating: isic2020/train/ISIC_8814657.jpg
#   inflating: isic2020/train/ISIC_8814672.jpg
#   inflating: isic2020/train/ISIC_8814735.jpg
#   inflating: isic2020/train/ISIC_8814843.jpg
#   inflating: isic2020/train/ISIC_8815782.jpg
#   inflating: isic2020/train/ISIC_8815828.jpg
# ...
#   inflating: isic2020/train/ISIC_9893956.jpg
#   inflating: isic2020/train/ISIC_9894283.jpg
#   inflating: isic2020/train/ISIC_9894617.jpg
#   inflating: isic2020/train/ISIC_9894782.jpg
#   inflating: isic2020/train/ISIC_9895220.jpg
#   inflating: isic2020/train/ISIC_9895436.jpg
#   inflating: isic2020/train/ISIC_9895582.jpg
#   inflating: isic2020/train/ISIC_9895881.jpg
#   inflating: isic2020/train/ISIC_9896192.jpg
#   inflating: isic2020/train/ISIC_9896454.jpg
#   inflating: isic2020/train/ISIC_9896801.jpg
#   inflating: isic2020/train/ISIC_9896815.jpg
#   inflating: isic2020/train/ISIC_9898107.jpg
#   inflating: isic2020/train/ISIC_9898447.jpg
#   inflating: isic2020/train/ISIC_9898848.jpg
#   inflating: isic2020/train/ISIC_9898859.jpg
#   inflating: isic2020/train/ISIC_9899140.jpg
#   inflating: isic2020/train/ISIC_9899644.jpg
#   inflating: isic2020/train/ISIC_9899912.jpg
#   inflating: isic2020/train/ISIC_9899949.jpg
#   inflating: isic2020/train/ISIC_9900191.jpg
#   inflating: isic2020/train/ISIC_9900262.jpg
#   inflating: isic2020/train/ISIC_9900623.jpg
#   inflating: isic2020/train/ISIC_9900876.jpg
#   inflating: isic2020/train/ISIC_9901014.jpg
#   inflating: isic2020/train/ISIC_9901093.jpg
#   inflating: isic2020/train/ISIC_9901847.jpg
#   inflating: isic2020/train/ISIC_9901871.jpg
#   inflating: isic2020/train/ISIC_9902648.jpg
#   inflating: isic2020/train/ISIC_9903000.jpg
#   inflating: isic2020/train/ISIC_9903033.jpg
#   inflating: isic2020/train/ISIC_9904494.jpg
#   inflating: isic2020/train/ISIC_9905269.jpg
#   inflating: isic2020/train/ISIC_9905633.jpg
#   inflating: isic2020/train/ISIC_9906218.jpg
#   inflating: isic2020/train/ISIC_9906378.jpg
#   inflating: isic2020/train/ISIC_9906657.jpg
#   inflating: isic2020/train/ISIC_9906799.jpg
#   inflating: isic2020/train/ISIC_9907084.jpg
#   inflating: isic2020/train/ISIC_9907211.jpg
#   inflating: isic2020/train/ISIC_9907793.jpg
#   inflating: isic2020/train/ISIC_9907938.jpg
#   inflating: isic2020/train/ISIC_9908982.jpg
#   inflating: isic2020/train/ISIC_9909173.jpg
#   inflating: isic2020/train/ISIC_9909314.jpg
#   inflating: isic2020/train/ISIC_9909655.jpg
#   inflating: isic2020/train/ISIC_9909722.jpg
#   inflating: isic2020/train/ISIC_9909792.jpg
#   inflating: isic2020/train/ISIC_9910101.jpg
#   inflating: isic2020/train/ISIC_9910480.jpg
#   inflating: isic2020/train/ISIC_9910611.jpg
#   inflating: isic2020/train/ISIC_9910791.jpg
#   inflating: isic2020/train/ISIC_9910854.jpg
#   inflating: isic2020/train/ISIC_9912475.jpg
#   inflating: isic2020/train/ISIC_9913091.jpg
#   inflating: isic2020/train/ISIC_9913300.jpg
#   inflating: isic2020/train/ISIC_9913406.jpg
#   inflating: isic2020/train/ISIC_9913453.jpg
#   inflating: isic2020/train/ISIC_9913573.jpg
#   inflating: isic2020/train/ISIC_9913667.jpg
#   inflating: isic2020/train/ISIC_9913914.jpg
#   inflating: isic2020/train/ISIC_9914108.jpg
#   inflating: isic2020/train/ISIC_9914240.jpg
#   inflating: isic2020/train/ISIC_9914767.jpg
#   inflating: isic2020/train/ISIC_9915342.jpg
#   inflating: isic2020/train/ISIC_9915649.jpg
#   inflating: isic2020/train/ISIC_9915699.jpg
#   inflating: isic2020/train/ISIC_9915822.jpg
#   inflating: isic2020/train/ISIC_9915927.jpg
#   inflating: isic2020/train/ISIC_9916654.jpg
#   inflating: isic2020/train/ISIC_9916907.jpg
#   inflating: isic2020/train/ISIC_9917477.jpg
#   inflating: isic2020/train/ISIC_9917640.jpg
#   inflating: isic2020/train/ISIC_9917899.jpg
#   inflating: isic2020/train/ISIC_9917958.jpg
#   inflating: isic2020/train/ISIC_9918277.jpg
#   inflating: isic2020/train/ISIC_9918333.jpg
#   inflating: isic2020/train/ISIC_9918523.jpg
#   inflating: isic2020/train/ISIC_9918528.jpg
#   inflating: isic2020/train/ISIC_9918584.jpg
#   inflating: isic2020/train/ISIC_9918598.jpg
#   inflating: isic2020/train/ISIC_9918806.jpg
#   inflating: isic2020/train/ISIC_9918829.jpg
#   inflating: isic2020/train/ISIC_9919143.jpg
#   inflating: isic2020/train/ISIC_9919255.jpg
#   inflating: isic2020/train/ISIC_9919374.jpg
#   inflating: isic2020/train/ISIC_9920034.jpg
#   inflating: isic2020/train/ISIC_9920161.jpg
#   inflating: isic2020/train/ISIC_9921461.jpg
#   inflating: isic2020/train/ISIC_9921695.jpg
#   inflating: isic2020/train/ISIC_9921747.jpg
#   inflating: isic2020/train/ISIC_9921831.jpg
#   inflating: isic2020/train/ISIC_9922133.jpg
#   inflating: isic2020/train/ISIC_9922430.jpg
#   inflating: isic2020/train/ISIC_9923018.jpg
#   inflating: isic2020/train/ISIC_9923630.jpg
#   inflating: isic2020/train/ISIC_9924151.jpg
#   inflating: isic2020/train/ISIC_9924303.jpg
#   inflating: isic2020/train/ISIC_9924877.jpg
#   inflating: isic2020/train/ISIC_9924951.jpg
#   inflating: isic2020/train/ISIC_9924993.jpg
#   inflating: isic2020/train/ISIC_9925445.jpg
#   inflating: isic2020/train/ISIC_9925786.jpg
#   inflating: isic2020/train/ISIC_9925849.jpg
#   inflating: isic2020/train/ISIC_9926111.jpg
#   inflating: isic2020/train/ISIC_9926163.jpg
#   inflating: isic2020/train/ISIC_9926931.jpg
#   inflating: isic2020/train/ISIC_9927067.jpg
#   inflating: isic2020/train/ISIC_9927102.jpg
#   inflating: isic2020/train/ISIC_9927221.jpg
#   inflating: isic2020/train/ISIC_9927490.jpg
#   inflating: isic2020/train/ISIC_9928124.jpg
#   inflating: isic2020/train/ISIC_9928421.jpg
#   inflating: isic2020/train/ISIC_9928774.jpg
#   inflating: isic2020/train/ISIC_9929097.jpg
#   inflating: isic2020/train/ISIC_9929556.jpg
#   inflating: isic2020/train/ISIC_9930252.jpg
#   inflating: isic2020/train/ISIC_9930981.jpg
#   inflating: isic2020/train/ISIC_9931592.jpg
#   inflating: isic2020/train/ISIC_9931733.jpg
#   inflating: isic2020/train/ISIC_9932367.jpg
#   inflating: isic2020/train/ISIC_9932789.jpg
#   inflating: isic2020/train/ISIC_9933119.jpg
#   inflating: isic2020/train/ISIC_9933282.jpg
#   inflating: isic2020/train/ISIC_9933406.jpg
#   inflating: isic2020/train/ISIC_9933722.jpg
#   inflating: isic2020/train/ISIC_9933790.jpg
#   inflating: isic2020/train/ISIC_9934037.jpg
#   inflating: isic2020/train/ISIC_9934401.jpg
#   inflating: isic2020/train/ISIC_9934553.jpg
#   inflating: isic2020/train/ISIC_9935437.jpg
#   inflating: isic2020/train/ISIC_9935444.jpg
#   inflating: isic2020/train/ISIC_9935606.jpg
#   inflating: isic2020/train/ISIC_9935970.jpg
#   inflating: isic2020/train/ISIC_9936188.jpg
#   inflating: isic2020/train/ISIC_9936773.jpg
#   inflating: isic2020/train/ISIC_9936937.jpg
#   inflating: isic2020/train/ISIC_9937653.jpg
#   inflating: isic2020/train/ISIC_9938103.jpg
#   inflating: isic2020/train/ISIC_9938191.jpg
#   inflating: isic2020/train/ISIC_9938274.jpg
#   inflating: isic2020/train/ISIC_9938316.jpg
#   inflating: isic2020/train/ISIC_9939197.jpg
#   inflating: isic2020/train/ISIC_9939653.jpg
#   inflating: isic2020/train/ISIC_9939963.jpg
#   inflating: isic2020/train/ISIC_9940466.jpg
#   inflating: isic2020/train/ISIC_9940802.jpg
#   inflating: isic2020/train/ISIC_9940867.jpg
#   inflating: isic2020/train/ISIC_9941161.jpg
#   inflating: isic2020/train/ISIC_9941889.jpg
#   inflating: isic2020/train/ISIC_9942347.jpg
#   inflating: isic2020/train/ISIC_9942427.jpg
#   inflating: isic2020/train/ISIC_9943579.jpg
#   inflating: isic2020/train/ISIC_9944425.jpg
#   inflating: isic2020/train/ISIC_9944671.jpg
#   inflating: isic2020/train/ISIC_9944714.jpg
#   inflating: isic2020/train/ISIC_9944803.jpg
#   inflating: isic2020/train/ISIC_9944931.jpg
#   inflating: isic2020/train/ISIC_9945083.jpg
#   inflating: isic2020/train/ISIC_9945620.jpg
#   inflating: isic2020/train/ISIC_9945852.jpg
#   inflating: isic2020/train/ISIC_9945993.jpg
#   inflating: isic2020/train/ISIC_9946557.jpg
#   inflating: isic2020/train/ISIC_9946702.jpg
#   inflating: isic2020/train/ISIC_9946910.jpg
#   inflating: isic2020/train/ISIC_9947197.jpg
#   inflating: isic2020/train/ISIC_9947369.jpg
#   inflating: isic2020/train/ISIC_9947624.jpg
#   inflating: isic2020/train/ISIC_9948600.jpg
#   inflating: isic2020/train/ISIC_9948815.jpg
#   inflating: isic2020/train/ISIC_9948820.jpg
#   inflating: isic2020/train/ISIC_9949745.jpg
#   inflating: isic2020/train/ISIC_9950853.jpg
#   inflating: isic2020/train/ISIC_9950866.jpg
#   inflating: isic2020/train/ISIC_9951949.jpg
#   inflating: isic2020/train/ISIC_9952408.jpg
#   inflating: isic2020/train/ISIC_9952575.jpg
#   inflating: isic2020/train/ISIC_9952872.jpg
#   inflating: isic2020/train/ISIC_9954010.jpg
#   inflating: isic2020/train/ISIC_9954349.jpg
#   inflating: isic2020/train/ISIC_9954582.jpg
#   inflating: isic2020/train/ISIC_9954915.jpg
#   inflating: isic2020/train/ISIC_9955092.jpg
#   inflating: isic2020/train/ISIC_9955163.jpg
#   inflating: isic2020/train/ISIC_9955179.jpg
#   inflating: isic2020/train/ISIC_9955255.jpg
#   inflating: isic2020/train/ISIC_9955935.jpg
#   inflating: isic2020/train/ISIC_9956125.jpg
#   inflating: isic2020/train/ISIC_9956374.jpg
#   inflating: isic2020/train/ISIC_9956395.jpg
#   inflating: isic2020/train/ISIC_9956400.jpg
#   inflating: isic2020/train/ISIC_9956744.jpg
#   inflating: isic2020/train/ISIC_9956957.jpg
#   inflating: isic2020/train/ISIC_9957107.jpg
#   inflating: isic2020/train/ISIC_9957298.jpg
#   inflating: isic2020/train/ISIC_9957389.jpg
#   inflating: isic2020/train/ISIC_9957720.jpg
#   inflating: isic2020/train/ISIC_9958062.jpg
#   inflating: isic2020/train/ISIC_9958346.jpg
#   inflating: isic2020/train/ISIC_9958613.jpg
#   inflating: isic2020/train/ISIC_9959011.jpg
#   inflating: isic2020/train/ISIC_9959593.jpg
#   inflating: isic2020/train/ISIC_9959813.jpg
#   inflating: isic2020/train/ISIC_9959917.jpg
#   inflating: isic2020/train/ISIC_9960578.jpg
#   inflating: isic2020/train/ISIC_9960584.jpg
#   inflating: isic2020/train/ISIC_9960804.jpg
#   inflating: isic2020/train/ISIC_9960855.jpg
#   inflating: isic2020/train/ISIC_9961652.jpg
#   inflating: isic2020/train/ISIC_9961808.jpg
#   inflating: isic2020/train/ISIC_9962329.jpg
#   inflating: isic2020/train/ISIC_9962388.jpg
#   inflating: isic2020/train/ISIC_9962534.jpg
#   inflating: isic2020/train/ISIC_9962720.jpg
#   inflating: isic2020/train/ISIC_9963177.jpg
#   inflating: isic2020/train/ISIC_9963692.jpg
#   inflating: isic2020/train/ISIC_9963967.jpg
#   inflating: isic2020/train/ISIC_9964362.jpg
#   inflating: isic2020/train/ISIC_9964568.jpg
#   inflating: isic2020/train/ISIC_9964609.jpg
#   inflating: isic2020/train/ISIC_9964816.jpg
#   inflating: isic2020/train/ISIC_9965174.jpg
#   inflating: isic2020/train/ISIC_9965556.jpg
#   inflating: isic2020/train/ISIC_9965754.jpg
#   inflating: isic2020/train/ISIC_9965843.jpg
#   inflating: isic2020/train/ISIC_9966185.jpg
#   inflating: isic2020/train/ISIC_9966425.jpg
#   inflating: isic2020/train/ISIC_9966978.jpg
#   inflating: isic2020/train/ISIC_9967383.jpg
#   inflating: isic2020/train/ISIC_9967671.jpg
#   inflating: isic2020/train/ISIC_9967715.jpg
#   inflating: isic2020/train/ISIC_9968564.jpg
#   inflating: isic2020/train/ISIC_9968669.jpg
#   inflating: isic2020/train/ISIC_9969263.jpg
#   inflating: isic2020/train/ISIC_9969907.jpg
#   inflating: isic2020/train/ISIC_9969993.jpg
#   inflating: isic2020/train/ISIC_9970004.jpg
#   inflating: isic2020/train/ISIC_9971202.jpg
#   inflating: isic2020/train/ISIC_9971280.jpg
#   inflating: isic2020/train/ISIC_9971473.jpg
#   inflating: isic2020/train/ISIC_9971896.jpg
#   inflating: isic2020/train/ISIC_9972518.jpg
#   inflating: isic2020/train/ISIC_9972557.jpg
#   inflating: isic2020/train/ISIC_9973015.jpg
#   inflating: isic2020/train/ISIC_9973089.jpg
#   inflating: isic2020/train/ISIC_9973322.jpg
#   inflating: isic2020/train/ISIC_9973459.jpg
#   inflating: isic2020/train/ISIC_9973526.jpg
#   inflating: isic2020/train/ISIC_9973894.jpg
#   inflating: isic2020/train/ISIC_9974166.jpg
#   inflating: isic2020/train/ISIC_9974299.jpg
#   inflating: isic2020/train/ISIC_9974613.jpg
#   inflating: isic2020/train/ISIC_9974860.jpg
#   inflating: isic2020/train/ISIC_9975037.jpg
#   inflating: isic2020/train/ISIC_9975260.jpg
#   inflating: isic2020/train/ISIC_9975949.jpg
#   inflating: isic2020/train/ISIC_9975974.jpg
#   inflating: isic2020/train/ISIC_9976418.jpg
#   inflating: isic2020/train/ISIC_9976478.jpg
#   inflating: isic2020/train/ISIC_9977219.jpg
#   inflating: isic2020/train/ISIC_9977346.jpg
#   inflating: isic2020/train/ISIC_9977580.jpg
#   inflating: isic2020/train/ISIC_9977672.jpg
#   inflating: isic2020/train/ISIC_9977784.jpg
#   inflating: isic2020/train/ISIC_9978107.jpg
#   inflating: isic2020/train/ISIC_9978282.jpg
#   inflating: isic2020/train/ISIC_9978328.jpg
#   inflating: isic2020/train/ISIC_9978498.jpg
#   inflating: isic2020/train/ISIC_9978602.jpg
#   inflating: isic2020/train/ISIC_9979425.jpg
#   inflating: isic2020/train/ISIC_9979438.jpg
#   inflating: isic2020/train/ISIC_9979486.jpg
#   inflating: isic2020/train/ISIC_9979765.jpg
#   inflating: isic2020/train/ISIC_9980055.jpg
#   inflating: isic2020/train/ISIC_9980068.jpg
#   inflating: isic2020/train/ISIC_9980854.jpg
#   inflating: isic2020/train/ISIC_9981194.jpg
#   inflating: isic2020/train/ISIC_9981394.jpg
#   inflating: isic2020/train/ISIC_9981558.jpg
#   inflating: isic2020/train/ISIC_9981925.jpg
#   inflating: isic2020/train/ISIC_9982060.jpg
#   inflating: isic2020/train/ISIC_9982091.jpg
#   inflating: isic2020/train/ISIC_9982623.jpg
#   inflating: isic2020/train/ISIC_9982953.jpg
#   inflating: isic2020/train/ISIC_9983616.jpg
#   inflating: isic2020/train/ISIC_9983657.jpg
#   inflating: isic2020/train/ISIC_9983696.jpg
#   inflating: isic2020/train/ISIC_9985141.jpg
#   inflating: isic2020/train/ISIC_9985224.jpg
#   inflating: isic2020/train/ISIC_9985776.jpg
#   inflating: isic2020/train/ISIC_9985905.jpg
#   inflating: isic2020/train/ISIC_9986040.jpg
#   inflating: isic2020/train/ISIC_9986333.jpg
#   inflating: isic2020/train/ISIC_9986563.jpg
#   inflating: isic2020/train/ISIC_9986760.jpg
#   inflating: isic2020/train/ISIC_9987485.jpg
#   inflating: isic2020/train/ISIC_9987617.jpg
#   inflating: isic2020/train/ISIC_9987757.jpg
#   inflating: isic2020/train/ISIC_9987808.jpg
#   inflating: isic2020/train/ISIC_9988236.jpg
#   inflating: isic2020/train/ISIC_9988492.jpg
#   inflating: isic2020/train/ISIC_9988559.jpg
#   inflating: isic2020/train/ISIC_9989082.jpg
#   inflating: isic2020/train/ISIC_9989156.jpg
#   inflating: isic2020/train/ISIC_9989485.jpg
#   inflating: isic2020/train/ISIC_9989617.jpg
#   inflating: isic2020/train/ISIC_9989641.jpg
#   inflating: isic2020/train/ISIC_9989680.jpg
#   inflating: isic2020/train/ISIC_9989936.jpg
#   inflating: isic2020/train/ISIC_9990676.jpg
#   inflating: isic2020/train/ISIC_9991394.jpg
#   inflating: isic2020/train/ISIC_9991451.jpg
#   inflating: isic2020/train/ISIC_9991492.jpg
#   inflating: isic2020/train/ISIC_9991967.jpg
#   inflating: isic2020/train/ISIC_9992950.jpg
#   inflating: isic2020/train/ISIC_9994033.jpg
#   inflating: isic2020/train/ISIC_9994122.jpg
#   inflating: isic2020/train/ISIC_9994125.jpg
#   inflating: isic2020/train/ISIC_9994390.jpg
#   inflating: isic2020/train/ISIC_9994768.jpg
#   inflating: isic2020/train/ISIC_9995140.jpg
#   inflating: isic2020/train/ISIC_9995166.jpg
#   inflating: isic2020/train/ISIC_9995691.jpg
#   inflating: isic2020/train/ISIC_9995837.jpg
#   inflating: isic2020/train/ISIC_9996128.jpg
#   inflating: isic2020/train/ISIC_9996662.jpg
#   inflating: isic2020/train/ISIC_9997221.jpg
#   inflating: isic2020/train/ISIC_9997614.jpg
#   inflating: isic2020/train/ISIC_9998152.jpg
#   inflating: isic2020/train/ISIC_9998240.jpg
#   inflating: isic2020/train/ISIC_9998582.jpg
#   inflating: isic2020/train/ISIC_9998682.jpg
#   inflating: isic2020/train/ISIC_9998937.jpg
#   inflating: isic2020/train/ISIC_9998965.jpg
#   inflating: isic2020/train/ISIC_9999127.jpg
#   inflating: isic2020/train/ISIC_9999134.jpg
#   inflating: isic2020/train/ISIC_9999320.jpg
#   inflating: isic2020/train/ISIC_9999515.jpg
#   inflating: isic2020/train/ISIC_9999666.jpg
#   inflating: isic2020/train/ISIC_9999806.jpg

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import SpatialDropout2D 
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import *
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.applications.vgg16 import preprocess_input, VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras import Model


filterwarnings('ignore')
np.random.seed(101)
EFNS = [EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, 
        EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7]

# %%
root_path = '/content/isic2020/'
IMAGE_DIR = ( '/content/isic2020/train')
panda_path = os.path.join(root_path, 'train.csv')
print(len(os.listdir(IMAGE_DIR)))
#os.path.join
# Out:
# 33126

# %%
def preprocess(df):
    for index, img in enumerate(df['image_name']):
        img = img+'.jpg'
        df['image_name'][index]=img
    # df.drop(['UNK'], axis=1, inplace=True)

# %%
def train_val_test_split(df, test_len=1000, val_ratio=0.2):
    test_rows = (np.random.rand(1000)*df.shape[0]).astype(int)
    test_df =  df.iloc[test_rows]
    test_df = test_df.reset_index().drop(['index'], axis=1)
    df.drop(test_rows, axis=0, inplace=True)
    df = df.reset_index().drop(['index'], axis=1)
    val_rows = (np.random.rand(int(val_ratio*df.shape[0]))*df.shape[0]).astype(int)
    val_df = df.iloc[val_rows]
    df.drop(val_rows, axis=0, inplace=True)
    val_df = val_df.reset_index().drop(['index'], axis=1)
    test_df = test_df.reset_index().drop(['index'], axis=1)
    df = df.reset_index().drop(['index'], axis=1)
#     int_dict = {'MEL':int, 'NV':int, 'BCC':int, 'AK':int, 'BKL':int, 'DF':int, 'VASC':int, 'SCC':int}
#     df = df.astype(int_dict) 
#     val_df = val_df.astype(int_dict)
#     test_df = test_df.astype(int_dict)
    return df, val_df, test_df

# %%
full_df = pd.read_csv(panda_path)
preprocess(full_df)
train_df, val_df, test_df = train_val_test_split(full_df)
labels=train_df.target.unique()
print(labels)
train_df.head()
# Out:
# [0 1]
#          image_name  patient_id     sex  ...  tfrecord width height
# 0  ISIC_2637011.jpg  IP_7279968    male  ...         0  6000   4000
# 1  ISIC_0015719.jpg  IP_3075186  female  ...         0  6000   4000
# 2  ISIC_0052212.jpg  IP_2842074  female  ...         6  1872   1053
# 3  ISIC_0068279.jpg  IP_6890425  female  ...         0  1872   1053
# 4  ISIC_0074268.jpg  IP_8723313  female  ...        11  6000   4000
#
# [5 rows x 11 columns]

# %%
def get_segmentation_model(weights_path, inputs=None):
  # Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
  INPUT_CHANNELS = 3
  # Number of output masks (1 in case you predict only one type of objects)
  OUTPUT_MASK_CHANNELS = 1
  # Pretrained weights
  def double_conv_layer(x, size, dropout=0.40, batch_norm=True, name = None):
    
    axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same',name=name)(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv

  dropout_val=0.50
    
  if inputs is None:  
    inputs = Input((256, 256, INPUT_CHANNELS))
  axis = 3
  filters = 32

  conv_256 = double_conv_layer(inputs, filters)
  pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_256)

  conv_112 = double_conv_layer(pool_112, 2*filters)
  pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

  conv_56 = double_conv_layer(pool_56, 4*filters)
  pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

  conv_28 = double_conv_layer(pool_28, 8*filters)
  pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

  conv_14 = double_conv_layer(pool_14, 16*filters)
  pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

  conv_7 = double_conv_layer(pool_7, 32*filters, name='features')

  up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
  up_conv_14 = double_conv_layer(up_14, 16*filters)

  up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
  up_conv_28 = double_conv_layer(up_28, 8*filters)

  up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
  up_conv_56 = double_conv_layer(up_56, 4*filters)

  up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
  up_conv_112 = double_conv_layer(up_112, 2*filters)

  up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_256], axis=axis)
  up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

  conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
  conv_final = Activation('sigmoid')(conv_final)
  pred = Reshape((256,256))(conv_final)
  model = Model(inputs, pred, name="UNET_256")
  model.load_weights(weights_path)
  return model

# %%
segmentation_weights = '/content/drive/MyDrive/Upwork/Skin Classification/segmentation_weights/segmentation_256_unet_final'
segmentator = get_segmentation_model(weights_path=segmentation_weights)
segmentator.trainable = False

# %%
target_w = 256
target_h = 256

def crop_mask_prep(im):
    im = np.reshape(im,(1,target_w,target_h,3))
    im = im*(1./255)
    mask = segmentator.predict(im)
    im = np.squeeze(im)
    mask = np.squeeze(mask)
    mask_ = np.dstack((mask,mask,mask))
    mask_ = np.uint8(mask_*255)
    try:
        maskgray = cv2.cvtColor(mask_,cv2.COLOR_BGR2GRAY)
        ret,thresh = cv2.threshold(maskgray,127,255,cv2.THRESH_BINARY)
        # find contours 
        contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        areas = [cv2.contourArea(contour) for contour in contours]
        cnt = contours[np.argmax(areas)]
        # straight rectangle
        x,y,w,h = cv2.boundingRect(cnt)
        final = im[y:y+h, x:x+w]
        final = cv2.resize(final, (target_w,target_h))
        final = np.uint8(final*255)
    except:
        final = np.uint8(im*255)

    
    return final

# %%
def get_generator(df=train_df, image_dir=IMAGE_DIR, x_col='image_name', y_cols='target', shuffle=True, batch_size=32, seed=42, target_w = 256, target_h = 256):
    
    
    print("getting  generator...") 
    # normalize images
    image_generator1 = ImageDataGenerator(
        # rescale=1./255,  
        featurewise_center = True,
        featurewise_std_normalization = True,
        horizontal_flip = True,
        vertical_flip = True,
        # rotation_range = 15,
#         preprocessing_function = preprocessing
        # samplewise_center=True,
        # samplewise_std_normalization= True
        )
    
    # flow from directory with specified batch size
    # and target image size
    generator1 = image_generator1.flow_from_dataframe(
            dataframe=df,
            directory=image_dir,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            shuffle=shuffle,
            seed=seed,
            target_size=(target_w,target_h))
    
    return generator1

# %%
batch_size = 32
train_generator = get_generator(df = train_df, batch_size = batch_size)
valid_generator = get_generator(df = val_df, batch_size = batch_size)
test_generator = get_generator(df = test_df, batch_size = batch_size)
# Out:
# getting  generator...
# Found 26313 validated image filenames.
# getting  generator...
# Found 6428 validated image filenames.
# getting  generator...
# Found 1000 validated image filenames.

# %%
class_labels = train_df['target'].values
class_labels.shape
# Out:
# (26313,)

# %%
def compute_class_freqs(labels):

    N = labels.shape[0]
    
    positive_frequencies = np.mean(labels, axis=0)
    negative_frequencies = 1 - positive_frequencies

    return positive_frequencies, negative_frequencies

# %%
freq_pos, freq_neg = compute_class_freqs(class_labels)

pos_weights = freq_neg
neg_weights = freq_pos

# %%
pos_weights
# Out:
# 0.9829361912362711

# %%
def get_weighted_loss(pos_weights, neg_weights, epsilon=1e-7):
    
    def weighted_loss(y_true, y_pred):
        
        # initialize loss to zero
        
        y_true = tf.cast(y_true, tf.float32)
        

        
            # for each class, add average weighted loss for that class 
        loss = K.mean(-(pos_weights*y_true*K.log(y_pred+epsilon)
                          + neg_weights*(1-y_true)*K.log((1-y_pred)+epsilon)))
        return loss
    
    return weighted_loss

# %%
x,y = next(train_generator)

# %%
i = 8
plt.imshow(np.uint8(x[i]))

# %%
np.max(x[i])
# Out:
# 255.0

# %%
x, y = next(valid_generator)

# %%
i = 8
plt.imshow(np.uint8(x[i]))

# %%
x, y = next(test_generator)

i = 8
plt.imshow(np.uint8(x[i]))

# %%
def get_classifier_model(dim = 256, ef = 0):
    ### Base Model ###
    # Input
    
    input1 = Input(shape = (dim, dim, 3))
    
    # Base EfficientNet pretrained model
    base = EFNS[ef](
        input_shape = (dim, dim, 3),
        weights = "imagenet",
        include_top = False,
        # pooling = 'avg'
    )
    x1 = base(input1)    
    x1 = Conv2D(512, (3, 3), padding='same',name='effnet_features1', activation = "relu")(x1)
    x1 = tf.keras.layers.GlobalAveragePooling2D()(x1)
    
    x = Dense(128, activation = "relu")(x1)
   
  
    ### Rebuild top ###
    x = Dense(1, activation = "sigmoid")(x)


    model = Model(inputs = input1, outputs = x)
    model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.AUC(from_logits=False)])
    # model.compile(optimizer= 'adam', loss=get_weighted_loss(pos_weights, neg_weights), metrics=[tf.keras.metrics.AUC(from_logits=False)])
   
    return model

# %%
model = get_classifier_model()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 8, 8, 1280)       4049571
#
#  effnet_features1 (Conv2D)   (None, 8, 8, 512)         5898752
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10,014,116
# Trainable params: 9,972,093
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=3, verbose=1)
checkpoint_filepath = '/content/drive/MyDrive/Upwork/Skin Classification/models/no_multiscale_B0_2020'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_auc',
    mode='max',
    verbose = 1,
    save_best_only=True)

# %%
STEP_SIZE_TRAIN=len(train_df)//batch_size
STEP_SIZE_VALID= len(val_df)//batch_size
STEP_SIZE_TEST=len(test_df)//batch_size
history = model.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN, validation_data=valid_generator,verbose=1, 
                        validation_steps=STEP_SIZE_VALID, epochs=25, callbacks=[callback, model_checkpoint_callback])
# Out:
# Epoch 1/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0963 - auc: 0.7117
# Epoch 00001: val_auc improved from -inf to 0.79061, saving model to /content/drive/MyDrive/Upwork/Skin Classification/models/no_multiscale_B0_2020
# 822/822 [==============================] - 276s 320ms/step - loss: 0.0963 - auc: 0.7117 - val_loss: 0.0970 - val_auc: 0.7906
# Epoch 2/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0758 - auc: 0.7990
# Epoch 00002: val_auc improved from 0.79061 to 0.88005, saving model to /content/drive/MyDrive/Upwork/Skin Classification/models/no_multiscale_B0_2020
# 822/822 [==============================] - 261s 318ms/step - loss: 0.0758 - auc: 0.7990 - val_loss: 0.0828 - val_auc: 0.8800
# Epoch 3/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0724 - auc: 0.8309
# Epoch 00003: val_auc did not improve from 0.88005
# 822/822 [==============================] - 261s 317ms/step - loss: 0.0724 - auc: 0.8309 - val_loss: 0.0821 - val_auc: 0.8593
# Epoch 4/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0718 - auc: 0.8485
# Epoch 00004: val_auc did not improve from 0.88005
# 822/822 [==============================] - 261s 317ms/step - loss: 0.0718 - auc: 0.8485 - val_loss: 0.0830 - val_auc: 0.8687
# Epoch 5/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0699 - auc: 0.8527
# Epoch 00005: val_auc improved from 0.88005 to 0.89072, saving model to /content/drive/MyDrive/Upwork/Skin Classification/models/no_multiscale_B0_2020
# 822/822 [==============================] - 261s 317ms/step - loss: 0.0699 - auc: 0.8527 - val_loss: 0.0800 - val_auc: 0.8907
# Epoch 6/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0689 - auc: 0.8593
# Epoch 00006: val_auc did not improve from 0.89072
# 822/822 [==============================] - 259s 315ms/step - loss: 0.0689 - auc: 0.8593 - val_loss: 0.0856 - val_auc: 0.8294
# Epoch 7/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0673 - auc: 0.8662
# Epoch 00007: val_auc did not improve from 0.89072
# 822/822 [==============================] - 258s 314ms/step - loss: 0.0673 - auc: 0.8662 - val_loss: 0.0824 - val_auc: 0.8449
# Epoch 8/25
# 822/822 [==============================] - ETA: 0s - loss: 0.0662 - auc: 0.8735
# Epoch 00008: val_auc did not improve from 0.89072
# 822/822 [==============================] - 258s 314ms/step - loss: 0.0662 - auc: 0.8735 - val_loss: 0.0870 - val_auc: 0.8116
# Epoch 00008: early stopping

# %%
model.load_weights(checkpoint_filepath)

# %%
loss, val_auc = model.evaluate(valid_generator)
print(val_auc)
# Out:
# 201/201 [==============================] - 19s 96ms/step - loss: 0.0801 - auc: 0.8851
# 0.8850942850112915

# %%
test_loss, test_auc = model.evaluate(test_generator)
print(test_auc)
# Out:
# 32/32 [==============================] - 3s 98ms/step - loss: 0.0648 - auc: 0.8830
# 0.8830348253250122

# %%
# # from tensorflow.keras.preprocessing import image
# # from sklearn.metrics import roc_auc_score, roc_curve
# # from tensorflow.compat.v1.logging import INFO, set_verbosity
# # import cv2

# from keras.preprocessing import image
# from sklearn.metrics import roc_auc_score, roc_curve
# from tensorflow.compat.v1.logging import INFO, set_verbosity
# import cv2

# def get_roc_curve(labels, predicted_vals, generator):
#     auc_roc_vals = []
#     for i in range(len(labels)):
#         try:
#             gt = generator.labels[:, i]
#             pred = predicted_vals[:, i]
#             auc_roc = roc_auc_score(gt, pred)
#             auc_roc_vals.append(auc_roc)
#             fpr_rf, tpr_rf, _ = roc_curve(gt, pred)
#             plt.figure(1, figsize=(10, 10))
#             plt.plot([0, 1], [0, 1], 'k--')
#             plt.plot(fpr_rf, tpr_rf,
#                      label=labels[i] + " (" + str(round(auc_roc, 3)) + ")")
#             plt.xlabel('False positive rate')
#             plt.ylabel('True positive rate')
#             plt.title('ROC curve')
#             plt.legend(loc='best')
#         except:
#             print(
#                 f"Error in generating ROC curve for {labels[i]}. "
#                 f"Dataset lacks enough examples."
#             )
#     plt.show()
#     return auc_roc_vals

# def get_accuracy(generator, predicted_vals):
#   acc = np.zeros(len(labels))
#   for i in range(len(labels)):
#     pred = np.int32(predicted_vals[:,i]>0.5)
#     gt = generator.labels[:, i]
#     acc[i] = np.sum(pred==gt)/len(pred)
#   return acc

# %%
# from tqdm import tqdm
# def get_predictions(generator, steps):
#     preds = []
#     gt = []
#     cnt = 0
#     for data, th in tqdm(generator):
#         preds.extend(model.predict(data))
#         gt.extend(th)
#         cnt += 1
#         if(cnt>= steps):
#             break
#     return preds, gt

# %%
# predicted_vals = model.predict_generator(valid_generator, steps = len(valid_generator), verbose =1)

# %%
# auc_rocs = get_roc_curve(labels, predicted_vals, valid_generator)

# %%
# print([labels[i]+" : {0}".format(round(auc_rocs[i],3)) for i in range(len(labels))])
# print('Mean AUC: {0}'.format(np.mean(auc_rocs)))

# %%
# val_acc = get_accuracy(valid_generator, predicted_vals)
# print([labels[i]+" : {0}".format(round(val_acc[i],3)) for i in range(len(labels))])
# print('Mean ACC: {0}'.format(np.mean(val_acc)))

# %%
# predicted_test = model.predict_generator(test_generator, steps = len(test_generator), verbose=1)

# %%
# auc_rocs_test = get_roc_curve(labels, predicted_test, test_generator)

# %%
# print([labels[i]+" : {0}".format(round(auc_rocs_test[i],3)) for i in range(len(labels))])
# print('Mean AUC: {0}'.format(np.mean(auc_rocs_test)))

# %%
# test_acc = get_accuracy(test_generator, predicted_test)

# %%
# print([labels[i]+" : {0}".format(round(test_acc[i],3)) for i in range(len(labels))])
# print('Mean ACC: {0}'.format(np.mean(test_acc)))
